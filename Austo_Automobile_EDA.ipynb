# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("austo_automobile.csv")
# read the dataset

# %% [markdown]
# ### Data profiling

# %%
df.head()
# to show top 5 rows
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %%
df.shape
# to check  total rows and columns - 1581 rows, 14 columns
# Out:
# (1581, 14)

# %%
df.info()
# to check basic information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.1+ KB

# %%
df.describe()
# Out:
#                Age  No_of_Dependents        Salary  Partner_salary  \
# count  1581.000000       1581.000000   1581.000000     1475.000000
# mean     31.922201          2.457938  60392.220114    20225.559322
# std       8.425978          0.943483  14674.825044    19573.149277
# min      22.000000          0.000000  30000.000000        0.000000
# 25%      25.000000          2.000000  51900.000000        0.000000
# 50%      29.000000          2.000000  59500.000000    25600.000000
# 75%      38.000000          3.000000  71800.000000    38300.000000
# max      54.000000          4.000000  99300.000000    80500.000000
#
#         Total_salary         Price
# count    1581.000000   1581.000000
# mean    79625.996205  35597.722960
# std     25545.857768  13633.636545
# min     30000.000000  18000.000000
# 25%     60500.000000  25000.000000
# 50%     78000.000000  31000.000000
# 75%     95900.000000  47000.000000
# max    171000.000000  70000.000000

# %%
df.isnull().sum()
# to check null values
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      53    Male   Business        Married  Post Graduate                 4
# 1      53   Femal   Salaried        Married  Post Graduate                 4
# 2      53  Female   Salaried        Married  Post Graduate                 3
# 3      53  Female   Salaried        Married       Graduate                 2
# 4      53    Male   Salaried        Married  Post Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1576   22    Male   Salaried         Single       Graduate                 2
# 1577   22    Male   Business        Married       Graduate                 4
# 1578   22    Male   Business         Single       Graduate                 2
# 1579   22    Male   Business        Married       Graduate                 3
# 1580   22    Male   Salaried        Married       Graduate                 4
#
# ...

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
df.Gender.value_counts()

# Check Value count
# Out:
# Gender
# Male      1199
# Female     327
# Femal        1
# Femle        1
# Name: count, dtype: int64

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Femal', 'Female', nan, 'Femle'], dtype=object)

# %%
df.Education.unique()
# Out:
# array(['Post Graduate', 'Graduate'], dtype=object)

# %%
df.Partner_working.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.Personal_loan.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df.House_loan.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df.Make.unique()
# Out:
# array(['SUV', 'Sedan', 'Hatchback'], dtype=object)

# %%
df.Partner_working.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Profession', 'Marital_status', 'Education',
#        'No_of_Dependents', 'Personal_loan', 'House_loan', 'Partner_working',
#        'Salary', 'Partner_salary', 'Total_salary', 'Price', 'Make'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning

# %%
df.Gender = df.Gender.replace(["Femal", "Femle"],["Female", "Female"])

# Replace mis spelled word with correct words

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
df.Gender = df.Gender.fillna("Male")

# Fill all the null value with mode which is Male

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      1252
# Female     329
# Name: count, dtype: int64

# %%
df.Gender.isna().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
df.Partner_salary= df.Total_salary - df.Salary

# Fill Partner_salary as difference of Total_Salary and Salary

# %%
df.Partner_salary.isna().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Age                 0
# Gender              0
# Profession          0
# Marital_status      0
# Education           0
# No_of_Dependents    0
# Personal_loan       0
# House_loan          0
# Partner_working     0
# Salary              0
# Partner_salary      0
# Total_salary        0
# Price               0
# Make                0
# dtype: int64

# %%
sns.countplot(df, x=df.Gender, hue=df.Gender)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(df, x = df.Profession, hue= df.Profession)
# Out:
# <Axes: xlabel='Profession', ylabel='count'>

# %%
sns.countplot(df, x = df.Marital_status, hue=df.Marital_status)
# Out:
# <Axes: xlabel='Marital_status', ylabel='count'>

# %%
sns.countplot(df, x=df.Education , hue=df.Education)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(df, x=df.Personal_loan , hue=df.Personal_loan)
# Out:
# <Axes: xlabel='Personal_loan', ylabel='count'>

# %%
sns.countplot(df, x=df.House_loan , hue=df.House_loan)
# Out:
# <Axes: xlabel='House_loan', ylabel='count'>

# %%
sns.countplot(df, x=df.Partner_working , hue=df.Partner_working)
# Out:
# <Axes: xlabel='Partner_working', ylabel='count'>

# %%
sns.countplot(df, x=df.Make , hue=df.Make)
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %%
sns.histplot(df.Age)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df.Salary)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sns.histplot(df.Partner_salary)
# Out:
# <Axes: xlabel='Partner_salary', ylabel='Count'>

# %%
sns.histplot(df.Total_salary)
# Out:
# <Axes: xlabel='Total_salary', ylabel='Count'>

# %%
sns.histplot(df.Price)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(df.No_of_Dependents)
# Out:
# <Axes: xlabel='No_of_Dependents', ylabel='Count'>

# %%
df.groupby(["Gender","Make"])["Make"].count()
# Out:
# Gender  Make
# Female  Hatchback     15
#         SUV          173
#         Sedan        141
# Male    Hatchback    567
#         SUV          124
#         Sedan        561
# Name: Make, dtype: int64

# %%
pd.crosstab(df.Gender, df.Make)
# Out:
# Make    Hatchback  SUV  Sedan
# Gender
# Female         15  173    141
# Male          567  124    561

# %% [markdown]
# ## EDA

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      1252
# Female     329
# Name: count, dtype: int64

# %%
df[df.Gender == "Male"] 

# Only Male data
# Out:
#       Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      53   Male   Business        Married  Post Graduate                 4
# 4      53   Male   Salaried        Married  Post Graduate                 3
# 7      52   Male   Salaried        Married       Graduate                 4
# 8      52   Male   Salaried        Married  Post Graduate                 4
# 9      52   Male   Salaried        Married  Post Graduate                 3
# ...   ...    ...        ...            ...            ...               ...
# 1576   22   Male   Salaried         Single       Graduate                 2
# 1577   22   Male   Business        Married       Graduate                 4
# 1578   22   Male   Business         Single       Graduate                 2
# 1579   22   Male   Business        Married       Graduate                 3
# 1580   22   Male   Salaried        Married       Graduate                 4
#
# ...

# %%
male = df[df.Gender == "Male"] [["Gender", "Make"]]

# %%
female = df[df.Gender == "Female"] [["Gender", "Make"]]

# %%
sam1 = male.sample(329).groupby("Make").count().rename(columns={"Gender":"Male"}) 

# Taking sample from male data

# %%
sam1
# Out:
#            Male
# Make
# Hatchback   147
# SUV          36
# Sedan       146

# %%
sam2 = male.sample(329).groupby("Make").count().rename(columns={"Gender":"Male"})

# %%
sam2
# Out:
#            Male
# Make
# Hatchback   146
# SUV          36
# Sedan       147

# %%
sam3 = male.sample(329).groupby("Make").count().rename(columns={"Gender":"Male"})

# %%
sam3
# Out:
#            Male
# Make
# Hatchback   145
# SUV          31
# Sedan       153

# %%
fem = female.sample(329).groupby("Make").count().rename(columns={"Gender":"Female"})

# %%
fem
# Out:
#            Female
# Make
# Hatchback      15
# SUV           173
# Sedan         141

# %%
suvm = [sam1.iloc[1][0], sam2.iloc[1][0], sam3.iloc[1][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\141928185.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvm = [sam1.iloc[1][0], sam2.iloc[1][0], sam3.iloc[1][0]]

# %%
suvf =  [fem.iloc[1][0], fem.iloc[1][0], fem.iloc[1][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\2830265943.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvf =  [fem.iloc[1][0], fem.iloc[1][0], fem.iloc[1][0]]

# %%
suvm
# Out:
# [np.int64(36), np.int64(36), np.int64(31)]

# %%
suvf
# Out:
# [np.int64(173), np.int64(173), np.int64(173)]

# %%
SUV = pd.DataFrame({"Male":suvm, "Female":suvf}, index = ["Sample1","Sample2","Sample3"])

# %%
SUV.plot.bar()
# Out:
# <Axes: >

# %%
# It is clearly visible that females are more interested in SUV

# %%
hbm = [sam1.iloc[0][0], sam2.iloc[0][0], sam3.iloc[0][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\3547072706.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hbm = [sam1.iloc[0][0], sam2.iloc[0][0], sam3.iloc[0][0]]

# %%
hbm
# Out:
# [np.int64(147), np.int64(146), np.int64(145)]

# %%
hbf = [fem.iloc[0][0], fem.iloc[0][0], fem.iloc[0][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\325322512.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hbf = [fem.iloc[0][0], fem.iloc[0][0], fem.iloc[0][0]]

# %%
hbf
# Out:
# [np.int64(15), np.int64(15), np.int64(15)]

# %%
HB = pd.DataFrame({"Male":hbm, "Female":hbf}, index = ["Sample1","Sample2","Sample3"])

# %%
HB
# Out:
#          Male  Female
# Sample1   147      15
# Sample2   146      15
# Sample3   145      15

# %%
HB.plot.bar()
# Out:
# <Axes: >

# %%
# Males are more interested in hatchback

# %%
sedm = [sam1.iloc[2][0], sam2.iloc[2][0], sam3.iloc[2][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\4159268242.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedm = [sam1.iloc[2][0], sam2.iloc[2][0], sam3.iloc[2][0]]

# %%
sedm
# Out:
# [np.int64(146), np.int64(147), np.int64(153)]

# %%
sedf = [fem.iloc[2][0], fem.iloc[2][0], fem.iloc[2][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\3169152082.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedf = [fem.iloc[2][0], fem.iloc[2][0], fem.iloc[2][0]]

# %%
sedf
# Out:
# [np.int64(141), np.int64(141), np.int64(141)]

# %%
Sedn = pd.DataFrame({"Male":sedm, "Female":sedf}, index = ["Sample1","Sample2","Sample3"])

# %%
Sedn
# Out:
#          Male  Female
# Sample1   146     141
# Sample2   147     141
# Sample3   153     141

# %%
Sedn.plot.bar()
# Out:
# <Axes: >

# %%
# Both have similar interest in Sedan 
# Although count of male is little bit greater than female in all samples

# %% [markdown]
# ### Profession

# %%
df.Profession.value_counts()
# Out:
# Profession
# Salaried    896
# Business    685
# Name: count, dtype: int64

# %%
df[df.Profession == "Salaried"]
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 1      53  Female   Salaried        Married  Post Graduate                 4
# 2      53  Female   Salaried        Married  Post Graduate                 3
# 3      53  Female   Salaried        Married       Graduate                 2
# 4      53    Male   Salaried        Married  Post Graduate                 3
# 5      53  Female   Salaried        Married  Post Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1569   22    Male   Salaried        Married       Graduate                 3
# 1574   22    Male   Salaried        Married       Graduate                 3
# 1575   22    Male   Salaried        Married       Graduate                 3
# 1576   22    Male   Salaried         Single       Graduate                 2
# 1580   22    Male   Salaried        Married       Graduate                 4
#
# ...

# %%
sal = df[df.Profession == "Salaried"] [["Profession", "Make"]]

# %%
bus = df[df.Profession == "Business"] [["Profession", "Make"]]

# %%
sal1 = sal.groupby("Make").count().rename(columns={"Profession":"Salaried"})

# %%
sal_suv = sal1.loc["SUV", "Salaried"]

# %%
suv_sal = sal[sal["Make"] == "SUV"]

# %%
bus1 = bus.groupby("Make").count().rename(columns={"Profession":"Business"})

# %%
bus_suv = bus1.loc["SUV", "Business"]

# %%
SUV_Pro = pd.DataFrame({"Salaried":sal_suv, "Business":bus_suv}, index = ["Sample"])

# %%
SUV_Pro.plot.bar()
# Out:
# <Axes: >

# %%
sal_hb = sal1.loc["Hatchback", "Salaried"]

# %%
sal_hb
# Out:
# np.int64(292)

# %%
bus_hb = bus1.loc["Hatchback", "Business"]

# %%
bus_hb
# Out:
# np.int64(290)

# %%
HB_Pro = pd.DataFrame({"Salaried":sal_hb, "Business":bus_hb}, index = ["Sample"])

# %%
HB_Pro.plot.bar()
# Out:
# <Axes: >

# %%
sal_sed = sal1.loc["Sedan", "Salaried"]

# %%
bus_sed = bus1.loc["Sedan", "Business"]

# %%
Sedan_Pro = pd.DataFrame({"Salaried":sal_sed, "Business":bus_sed}, index = ["Sample"])

# %%
Sedan_Pro.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ### Marital Status

# %%
df.Marital_status.value_counts()
# Out:
# Marital_status
# Married    1443
# Single      138
# Name: count, dtype: int64

# %%
df[df.Marital_status == "Married"]
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      53    Male   Business        Married  Post Graduate                 4
# 1      53  Female   Salaried        Married  Post Graduate                 4
# 2      53  Female   Salaried        Married  Post Graduate                 3
# 3      53  Female   Salaried        Married       Graduate                 2
# 4      53    Male   Salaried        Married  Post Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1574   22    Male   Salaried        Married       Graduate                 3
# 1575   22    Male   Salaried        Married       Graduate                 3
# 1577   22    Male   Business        Married       Graduate                 4
# 1579   22    Male   Business        Married       Graduate                 3
# 1580   22    Male   Salaried        Married       Graduate                 4
#
# ...

# %%
married = df[df.Marital_status == "Married"] [["Marital_status", "Make"]]

# %%
single = df[df.Marital_status == "Single"] [["Marital_status", "Make"]]

# %%
sam1 = married.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Married"})

# %%
sam2 = married.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Married"})

# %%
sam3 = married.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Married"})

# %%
sam4 = married.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Married"})

# %%
sam5 = married.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Married"})

# %%
sing = single.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Single"})

# %%
suv_mar = [sam1.iloc[1][0], sam2.iloc[1][0], sam3.iloc[1][0], sam4.iloc[1][0], sam5.iloc[1][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\1885616691.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suv_mar = [sam1.iloc[1][0], sam2.iloc[1][0], sam3.iloc[1][0], sam4.iloc[1][0], sam5.iloc[1][0]]

# %%
suv_mar
# Out:
# [np.int64(29), np.int64(33), np.int64(36), np.int64(34), np.int64(27)]

# %%
suv_sing = [sing.iloc[1][0], sing.iloc[1][0], sing.iloc[1][0], sing.iloc[1][0], sing.iloc[1][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\1900535273.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suv_sing = [sing.iloc[1][0], sing.iloc[1][0], sing.iloc[1][0], sing.iloc[1][0], sing.iloc[1][0]]

# %%
suv_sing
# Out:
# [np.int64(16), np.int64(16), np.int64(16), np.int64(16), np.int64(16)]

# %%
SUV_ms = pd.DataFrame({"Married":suv_mar, "Single":suv_sing}, index = ["Sample1", "Sample2", "Sample3", "Sample4", "Sample5"])

# %%
SUV_ms.plot.bar()
# Out:
# <Axes: >

# %%
# Married people are buying SUVs

# %%
hb_mar = [sam1.iloc[0][0], sam2.iloc[0][0], sam3.iloc[0][0], sam4.iloc[0][0], sam5.iloc[0][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\1014707754.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hb_mar = [sam1.iloc[0][0], sam2.iloc[0][0], sam3.iloc[0][0], sam4.iloc[0][0], sam5.iloc[0][0]]

# %%
hb_sing = [sing.iloc[0][0], sing.iloc[0][0], sing.iloc[0][0], sing.iloc[0][0], sing.iloc[0][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\2408620983.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hb_sing = [sing.iloc[0][0], sing.iloc[0][0], sing.iloc[0][0], sing.iloc[0][0], sing.iloc[0][0]]

# %%
HB_ms = pd.DataFrame({"Married":hb_mar, "Single":hb_sing}, index = ["Sample1", "Sample2", "Sample3", "Sample4", "Sample5"])

# %%
HB_ms.plot.bar()
# Out:
# <Axes: >

# %%
# Single people are buying more Hatchbacks

# %%
sed_mar = [sam1.iloc[2][0], sam2.iloc[2][0], sam3.iloc[2][0], sam4.iloc[2][0], sam5.iloc[2][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\345538781.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sed_mar = [sam1.iloc[2][0], sam2.iloc[2][0], sam3.iloc[2][0], sam4.iloc[2][0], sam5.iloc[2][0]]

# %%
sed_sing = [sing.iloc[2][0], sing.iloc[2][0], sing.iloc[2][0], sing.iloc[2][0], sing.iloc[2][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\4240866608.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sed_sing = [sing.iloc[2][0], sing.iloc[2][0], sing.iloc[2][0], sing.iloc[2][0], sing.iloc[2][0]]

# %%
Sedan_ms = pd.DataFrame({"Married":sed_mar, "Single":sed_sing}, index = ["Sample1", "Sample2", "Sample3", "Sample4", "Sample5"])

# %%
Sedan_ms.plot.bar()
# Out:
# <Axes: >

# %%
# Married People are buying more Sedans

# %% [markdown]
# ### Education

# %%
df.Education.value_counts()
# Out:
# Education
# Post Graduate    985
# Graduate         596
# Name: count, dtype: int64

# %%
pg = df[df.Education == "Post Graduate"] [["Education", "Make"]]

# %%
grad = df[df.Education == "Graduate"] [["Education", "Make"]]

# %%
grad
# Out:
#      Education       Make
# 3     Graduate        SUV
# 7     Graduate        SUV
# 12    Graduate        SUV
# 14    Graduate        SUV
# 20    Graduate        SUV
# ...        ...        ...
# 1576  Graduate  Hatchback
# 1577  Graduate  Hatchback
# 1578  Graduate  Hatchback
# 1579  Graduate  Hatchback
# 1580  Graduate  Hatchback
#
# [596 rows x 2 columns]

# %%
pg1 = pg.sample(596).groupby("Make").count().rename(columns={"Education":"Post Graduate"})

# %%
pg2 = pg.sample(389).groupby("Make").count().rename(columns={"Education":"Post Graduate"})

# %%
grad1 = grad.sample(596).groupby("Make").count().rename(columns={"Education":"Graduate"})

# %%
grad2 = grad.sample(389).groupby("Make").count().rename(columns={"Education":"Graduate"})

# %%
suv_pg = [pg1.iloc[1][0], pg1.iloc[1][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\4086452404.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suv_pg = [pg1.iloc[1][0], pg1.iloc[1][0]]

# %%
suv_grad = [grad1.iloc[1][0], grad2.iloc[1][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\1696431673.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suv_grad = [grad1.iloc[1][0], grad2.iloc[1][0]]

# %%
SUV_Ed = pd.DataFrame({"Post Graduate":suv_pg, "Graduate":suv_grad}, index = ["Sample1", "Sample2"])

# %%
SUV_Ed.plot.bar()
# Out:
# <Axes: >

# %%
hb_pg = [pg1.iloc[0][0], pg1.iloc[0][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\2498329352.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hb_pg = [pg1.iloc[0][0], pg1.iloc[0][0]]

# %%
hb_grad = [grad1.iloc[0][0], grad2.iloc[0][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\3192623297.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hb_grad = [grad1.iloc[0][0], grad2.iloc[0][0]]

# %%
HB_Ed = pd.DataFrame({"Post Graduate":hb_pg, "Graduate":hb_grad}, index = ["Sample1", "Sample2"])

# %%
HB_Ed.plot.bar()
# Out:
# <Axes: >

# %%
## Sedan is pending

# %% [markdown]
# ### Personal Loan

# %%
df.Personal_loan.value_counts()
# Out:
# Personal_loan
# Yes    792
# No     789
# Name: count, dtype: int64

# %%
df[df.Personal_loan == "Yes"]
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 1      53  Female   Salaried        Married  Post Graduate                 4
# 3      53  Female   Salaried        Married       Graduate                 2
# 6      53  Female   Salaried        Married  Post Graduate                 3
# 10     52    Male   Salaried        Married  Post Graduate                 4
# 12     50  Female   Salaried        Married       Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1572   22    Male   Business         Single       Graduate                 2
# 1573   22    Male   Business        Married       Graduate                 3
# 1574   22    Male   Salaried        Married       Graduate                 3
# 1575   22    Male   Salaried        Married       Graduate                 3
# 1579   22    Male   Business        Married       Graduate                 3
#
# ...

# %%
yes = df[df.Personal_loan == "Yes"] [["Personal_loan", "Make"]]

# %%
no = df[df.Personal_loan == "No"] [["Personal_loan", "Make"]]

# %%
yes1 = yes.groupby("Make").count().rename(columns={"Personal_loan":"Yes"})

# %%
no1 = no.groupby("Make").count().rename(columns={"Personal_loan":"No"})

# %%
yes_suv = yes1.loc["SUV", "Yes"]

# %%
yes_suv
# Out:
# np.int64(116)

# %%
no_suv = no1.loc["SUV", "No"]

# %%
no_suv
# Out:
# np.int64(181)

# %%
SUV_pl = pd.DataFrame({"Yes":yes_suv, "No":no_suv}, index = ["Sample1"])

# %%
SUV_pl.plot.bar()
# Out:
# <Axes: >

# %%
yes_hb = yes1.loc["Hatchback", "Yes"]

# %%
yes_hb
# Out:
# np.int64(291)

# %%
no_hb = no1.loc["Hatchback", "No"]

# %%
no_hb
# Out:
# np.int64(291)

# %%
HB_pl = pd.DataFrame({"Yes":yes_hb, "No":no_hb}, index = ["Sample1"])

# %%
HB_pl.plot.bar()
# Out:
# <Axes: >

# %%
yes_sed = yes1.loc["Sedan", "Yes"]

# %%
yes_sed
# Out:
# np.int64(385)

# %%
no_sed = no1.loc["Sedan", "No"]

# %%
no_sed
# Out:
# np.int64(317)

# %%
Sedan_pl = pd.DataFrame({"Yes":yes_sed, "No":no_sed}, index = ["Sample"])

# %%
Sedan_pl.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ### House Loan

# %%
df.House_loan.value_counts()
# Out:
# House_loan
# No     1054
# Yes     527
# Name: count, dtype: int64

# %%
df[df.House_loan == "No"]
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      53    Male   Business        Married  Post Graduate                 4
# 1      53  Female   Salaried        Married  Post Graduate                 4
# 2      53  Female   Salaried        Married  Post Graduate                 3
# 3      53  Female   Salaried        Married       Graduate                 2
# 4      53    Male   Salaried        Married  Post Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1572   22    Male   Business         Single       Graduate                 2
# 1573   22    Male   Business        Married       Graduate                 3
# 1575   22    Male   Salaried        Married       Graduate                 3
# 1577   22    Male   Business        Married       Graduate                 4
# 1580   22    Male   Salaried        Married       Graduate                 4
#
# ...

# %%
no_hl = df[df.House_loan == "No"] [["House_loan", "Make"]]

# %%
yes_hl = df[df.House_loan == "Yes"] [["House_loan", "Make"]]

# %%
sam_no1 = no_hl.sample(527).groupby("Make").count().rename(columns={"House_loan":"No"})

# %%
sam_no1
# Out:
#             No
# Make
# Hatchback  189
# SUV        134
# Sedan      204

# %%
sam_no2 = no_hl.sample(527).groupby("Make").count().rename(columns={"House_loan":"No"})

# %%
sam_no2
# Out:
#             No
# Make
# Hatchback  171
# SUV        151
# Sedan      205

# %%
sam_yes = yes_hl.sample(527).groupby("Make").count().rename(columns={"House_loan":"Yes"})

# %%
sam_yes
# Out:
#            Yes
# Make
# Hatchback  235
# SUV         22
# Sedan      270

# %%
suv_hl_no = [sam_no1.iloc[1][0], sam_no2.iloc[1][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\1980046089.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suv_hl_no = [sam_no1.iloc[1][0], sam_no2.iloc[1][0]]

# %%
suv_hl_yes = [sam_yes.iloc[1][0], sam_yes.iloc[1][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\1089651189.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suv_hl_yes = [sam_yes.iloc[1][0], sam_yes.iloc[1][0]]

# %%
suv_hl_no
# Out:
# [np.int64(134), np.int64(151)]

# %%
suv_hl_yes
# Out:
# [np.int64(22), np.int64(22)]

# %%
SUV_hl = pd.DataFrame({"no":suv_hl_no, "Yes":suv_hl_yes}, index = ["Sample1", "Sample2"])

# %%
SUV_hl.plot.bar()
# Out:
# <Axes: >

# %%
hb_hl_no = [sam_no1.iloc[0][0], sam_no2.iloc[0][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\3256304644.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hb_hl_no = [sam_no1.iloc[0][0], sam_no2.iloc[0][0]]

# %%
hb_hl_yes = [sam_yes.iloc[0][0], sam_yes.iloc[0][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\883655657.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hb_hl_yes = [sam_yes.iloc[0][0], sam_yes.iloc[0][0]]

# %%
HB_hl = pd.DataFrame({"No":hb_hl_no, "Yes":hb_hl_yes}, index=["Sample1", "Sample2"])

# %%
HB_hl.plot.bar()
# Out:
# <Axes: >

# %%
sed_hl_no = [sam_no1.iloc[2][0], sam_no2.iloc[2][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\507293126.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sed_hl_no = [sam_no1.iloc[2][0], sam_no2.iloc[2][0]]

# %%
sed_hl_yes = [sam_yes.iloc[2][0], sam_yes.iloc[2][0]]
# Out:
# C:\Users\shriy\AppData\Local\Temp\ipykernel_14932\4135225698.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sed_hl_yes = [sam_yes.iloc[2][0], sam_yes.iloc[2][0]]

# %%
Sedan_hl = pd.DataFrame({"No":sed_hl_no, "Yes":sed_hl_yes}, index=["Sample1", "Sample2"])

# %%
Sedan_hl.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ### Multivariate Analysis

# %%
new = pd.DataFrame(df.groupby(["Gender", "Profession", "Make"])["Make"].count())

# %%
new
# Out:
#                              Make
# Gender Profession Make
# Female Business   SUV          55
#                   Sedan        50
#        Salaried   Hatchback    15
#                   SUV         118
#                   Sedan        91
# Male   Business   Hatchback   290
#                   SUV          34
#                   Sedan       256
#        Salaried   Hatchback   277
#                   SUV          90
#                   Sedan       305

# %%
new2 = pd.DataFrame(df.groupby(["Gender", "Marital_status", "Make"])["Make"].count())

# %%
new2
# Out:
#                                  Make
# Gender Marital_status Make
# Female Married        Hatchback    14
#                       SUV         166
#                       Sedan       127
#        Single         Hatchback     1
#                       SUV           7
#                       Sedan        14
# Male   Married        Hatchback   484
#                       SUV         115
#                       Sedan       537
#        Single         Hatchback    83
#                       SUV           9
#                       Sedan        24

# %%
new3 = pd.DataFrame(df.groupby(["Gender", "Partner_working", "Make"])["Make"].count())

# %%
new3
# Out:
#                                   Make
# Gender Partner_working Make
# Female No              Hatchback     7
#                        SUV          80
#                        Sedan        64
#        Yes             Hatchback     8
#                        SUV          93
#                        Sedan        77
# Male   No              Hatchback   274
#                        SUV          64
#                        Sedan       224
#        Yes             Hatchback   293
#                        SUV          60
#                        Sedan       337

# %%
new.plot.bar()
# Out:
# <Axes: xlabel='Gender,Profession,Make'>

# %%
new2.plot.bar()
# Out:
# <Axes: xlabel='Gender,Marital_status,Make'>

# %%
new3.plot.bar()
# Out:
# <Axes: xlabel='Gender,Partner_working,Make'>
